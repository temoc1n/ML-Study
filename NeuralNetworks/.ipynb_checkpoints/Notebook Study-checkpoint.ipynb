# %%
from tensorflow import keras
import tensorflow as tf
from tensorflow.python.keras import layers, Sequential
from tensorflow.python.keras.activations import relu

import matplotlib.pyplot as plt

# %%
model = Sequential(layers.Dense(units=1, input_shape=[3], activation=relu))

x = tf.linspace(-1.0, 1.0, 100)

y = model.predict(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 5
#       1 model = Sequential(layers.Dense(units=1, input_shape=[11], activation=relu))
#       3 x = tf.linspace(-1.0, 1.0, 100)
# ----> 5 y = model.predict(x)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/keras/engine/training.py:1741, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1739 for step in data_handler.steps():
#    1740   callbacks.on_predict_batch_begin(step)
# -> 1741   tmp_batch_outputs = self.predict_function(iterator)
#    1742   if data_handler.should_sync:
#    1743     context.async_wait()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File /tmp/__autograph_generated_filey1t2opo8.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#
#     ValueError: Input 0 of layer sequential_8 is incompatible with the layer: expected axis -1 of input shape to have value 11 but received input with shape (None, 1)

# %%
plt.plot(x, y)

plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
  
# giving a title to my graph
plt.title('ReLu Network')
  
# function to show the plot
plt.show()
